# %%
# !pip install -U langchain-google-genai
# Out:
# Requirement already satisfied: langchain-google-genai in /usr/local/lib/python3.13/dist-packages (4.4.0)
# Requirement already satisfied: filetype<2.0.0,>=1.2.0 in /usr/local/lib/python3.13/dist-packages (from langchain-google-genai) (1.2.0)
# Requirement already satisfied: google-genai<3.0.0,>=2.20.0 in /usr/local/lib/python3.13/dist-packages (from langchain-google-genai) (2.22.0)
# Requirement already satisfied: langchain-core<2.0.0,>=1.6.1 in /usr/local/lib/python3.13/dist-packages (from langchain-google-genai) (1.6.1)
# Requirement already satisfied: pydantic<3.0.0,>=2.0.0 in /usr/local/lib/python3.13/dist-packages (from langchain-google-genai) (2.13.4)
# Requirement already satisfied: anyio<5.0.0,>=4.8.0 in /usr/local/lib/python3.13/dist-packages (from google-genai<3.0.0,>=2.20.0->langchain-google-genai) (4.14.2)
# Requirement already satisfied: google-auth<3.0.0,>=2.56.0 in /usr/local/lib/python3.13/dist-packages (from google-auth[requests]<3.0.0,>=2.56.0->google-genai<3.0.0,>=2.20.0->langchain-google-genai) (2.57.0)
# Requirement already satisfied: httpx<1.0.0,>=0.28.1 in /usr/local/lib/python3.13/dist-packages (from google-genai<3.0.0,>=2.20.0->langchain-google-genai) (0.28.1)
# Requirement already satisfied: requests<3.0.0,>=2.28.1 in /usr/local/lib/python3.13/dist-packages (from google-genai<3.0.0,>=2.20.0->langchain-google-genai) (2.32.4)
# Requirement already satisfied: tenacity<9.2.0,>=8.2.3 in /usr/local/lib/python3.13/dist-packages (from google-genai<3.0.0,>=2.20.0->langchain-google-genai) (9.1.4)
# Requirement already satisfied: websockets<17.0,>=13.0.0 in /usr/local/lib/python3.13/dist-packages (from google-genai<3.0.0,>=2.20.0->langchain-google-genai) (15.0.1)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.14.0 in /usr/local/lib/python3.13/dist-packages (from google-genai<3.0.0,>=2.20.0->langchain-google-genai) (4.16.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.13/dist-packages (from google-genai<3.0.0,>=2.20.0->langchain-google-genai) (1.9.0)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.13/dist-packages (from google-genai<3.0.0,>=2.20.0->langchain-google-genai) (1.3.1)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /usr/local/lib/python3.13/dist-packages (from langchain-core<2.0.0,>=1.6.1->langchain-google-genai) (1.33)
# Requirement already satisfied: langchain-protocol>=0.0.17 in /usr/local/lib/python3.13/dist-packages (from langchain-core<2.0.0,>=1.6.1->langchain-google-genai) (0.0.19)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in /usr/local/lib/python3.13/dist-packages (from langchain-core<2.0.0,>=1.6.1->langchain-google-genai) (0.11.1)
# Requirement already satisfied: packaging>=23.2.0 in /usr/local/lib/python3.13/dist-packages (from langchain-core<2.0.0,>=1.6.1->langchain-google-genai) (26.3)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in /usr/local/lib/python3.13/dist-packages (from langchain-core<2.0.0,>=1.6.1->langchain-google-genai) (6.0.3)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in /usr/local/lib/python3.13/dist-packages (from langchain-core<2.0.0,>=1.6.1->langchain-google-genai) (0.17.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.13/dist-packages (from pydantic<3.0.0,>=2.0.0->langchain-google-genai) (0.8.0)
# Requirement already satisfied: pydantic-core==2.46.4 in /usr/local/lib/python3.13/dist-packages (from pydantic<3.0.0,>=2.0.0->langchain-google-genai) (2.46.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.13/dist-packages (from pydantic<3.0.0,>=2.0.0->langchain-google-genai) (0.4.4)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.13/dist-packages (from anyio<5.0.0,>=4.8.0->google-genai<3.0.0,>=2.20.0->langchain-google-genai) (3.19)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.13/dist-packages (from google-auth<3.0.0,>=2.56.0->google-auth[requests]<3.0.0,>=2.56.0->google-genai<3.0.0,>=2.20.0->langchain-google-genai) (0.4.2)
# Requirement already satisfied: cryptography>=38.0.3 in /usr/local/lib/python3.13/dist-packages (from google-auth<3.0.0,>=2.56.0->google-auth[requests]<3.0.0,>=2.56.0->google-genai<3.0.0,>=2.20.0->langchain-google-genai) (50.0.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.13/dist-packages (from httpx<1.0.0,>=0.28.1->google-genai<3.0.0,>=2.20.0->langchain-google-genai) (2026.7.22)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.13/dist-packages (from httpx<1.0.0,>=0.28.1->google-genai<3.0.0,>=2.20.0->langchain-google-genai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.13/dist-packages (from httpcore==1.*->httpx<1.0.0,>=0.28.1->google-genai<3.0.0,>=2.20.0->langchain-google-genai) (0.16.0)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.13/dist-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.6.1->langchain-google-genai) (3.1.1)
# Requirement already satisfied: orjson>=3.9.14 in /usr/local/lib/python3.13/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.6.1->langchain-google-genai) (3.12.0)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /usr/local/lib/python3.13/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.6.1->langchain-google-genai) (1.0.0)
# Requirement already satisfied: xxhash>=3.0.0 in /usr/local/lib/python3.13/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.6.1->langchain-google-genai) (4.0.1)
# Requirement already satisfied: zstandard>=0.23.0 in /usr/local/lib/python3.13/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.6.1->langchain-google-genai) (0.25.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.13/dist-packages (from requests<3.0.0,>=2.28.1->google-genai<3.0.0,>=2.20.0->langchain-google-genai) (3.4.9)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.13/dist-packages (from requests<3.0.0,>=2.28.1->google-genai<3.0.0,>=2.20.0->langchain-google-genai) (2.5.0)
# Requirement already satisfied: cffi>=2.0.0 in /usr/local/lib/python3.13/dist-packages (from cryptography>=38.0.3->google-auth<3.0.0,>=2.56.0->google-auth[requests]<3.0.0,>=2.56.0->google-genai<3.0.0,>=2.20.0->langchain-google-genai) (2.1.1)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /usr/local/lib/python3.13/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.0,>=2.56.0->google-auth[requests]<3.0.0,>=2.56.0->google-genai<3.0.0,>=2.20.0->langchain-google-genai) (0.6.4)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.13/dist-packages (from cffi>=2.0.0->cryptography>=38.0.3->google-auth<3.0.0,>=2.56.0->google-auth[requests]<3.0.0,>=2.56.0->google-genai<3.0.0,>=2.20.0->langchain-google-genai) (3.0)

# %%
# !pip install -U langchain
# Out:
# Requirement already satisfied: langchain in /usr/local/lib/python3.13/dist-packages (1.3.17)
# Collecting langchain
#   Downloading langchain-1.4.0-py3-none-any.whl.metadata (6.2 kB)
# Requirement already satisfied: langchain-core<2.0.0,>=1.6.0 in /usr/local/lib/python3.13/dist-packages (from langchain) (1.6.1)
# Requirement already satisfied: langgraph<1.3.0,>=1.2.11 in /usr/local/lib/python3.13/dist-packages (from langchain) (1.2.11)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /usr/local/lib/python3.13/dist-packages (from langchain) (2.13.4)
# Requirement already satisfied: httpx<1.0.0,>=0.23.0 in /usr/local/lib/python3.13/dist-packages (from langchain-core<2.0.0,>=1.6.0->langchain) (0.28.1)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /usr/local/lib/python3.13/dist-packages (from langchain-core<2.0.0,>=1.6.0->langchain) (1.33)
# Requirement already satisfied: langchain-protocol>=0.0.17 in /usr/local/lib/python3.13/dist-packages (from langchain-core<2.0.0,>=1.6.0->langchain) (0.0.19)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in /usr/local/lib/python3.13/dist-packages (from langchain-core<2.0.0,>=1.6.0->langchain) (0.11.1)
# Requirement already satisfied: packaging>=23.2.0 in /usr/local/lib/python3.13/dist-packages (from langchain-core<2.0.0,>=1.6.0->langchain) (26.3)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in /usr/local/lib/python3.13/dist-packages (from langchain-core<2.0.0,>=1.6.0->langchain) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /usr/local/lib/python3.13/dist-packages (from langchain-core<2.0.0,>=1.6.0->langchain) (9.1.4)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in /usr/local/lib/python3.13/dist-packages (from langchain-core<2.0.0,>=1.6.0->langchain) (4.16.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in /usr/local/lib/python3.13/dist-packages (from langchain-core<2.0.0,>=1.6.0->langchain) (0.17.0)
# Requirement already satisfied: langgraph-checkpoint<5.0.0,>=4.1.0 in /usr/local/lib/python3.13/dist-packages (from langgraph<1.3.0,>=1.2.11->langchain) (4.2.0)
# Requirement already satisfied: langgraph-prebuilt<1.2.0,>=1.1.0 in /usr/local/lib/python3.13/dist-packages (from langgraph<1.3.0,>=1.2.11->langchain) (1.1.0)
# Requirement already satisfied: langgraph-sdk<0.5.0,>=0.4.2 in /usr/local/lib/python3.13/dist-packages (from langgraph<1.3.0,>=1.2.11->langchain) (0.4.3)
# Requirement already satisfied: xxhash>=3.5.0 in /usr/local/lib/python3.13/dist-packages (from langgraph<1.3.0,>=1.2.11->langchain) (4.0.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.13/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.8.0)
# Requirement already satisfied: pydantic-core==2.46.4 in /usr/local/lib/python3.13/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.46.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.13/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.4.4)
# Requirement already satisfied: anyio in /usr/local/lib/python3.13/dist-packages (from httpx<1.0.0,>=0.23.0->langchain-core<2.0.0,>=1.6.0->langchain) (4.14.2)
# Requirement already satisfied: certifi in /usr/local/lib/python3.13/dist-packages (from httpx<1.0.0,>=0.23.0->langchain-core<2.0.0,>=1.6.0->langchain) (2026.7.22)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.13/dist-packages (from httpx<1.0.0,>=0.23.0->langchain-core<2.0.0,>=1.6.0->langchain) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.13/dist-packages (from httpx<1.0.0,>=0.23.0->langchain-core<2.0.0,>=1.6.0->langchain) (3.19)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.13/dist-packages (from httpcore==1.*->httpx<1.0.0,>=0.23.0->langchain-core<2.0.0,>=1.6.0->langchain) (0.16.0)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.13/dist-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.6.0->langchain) (3.1.1)
# Requirement already satisfied: ormsgpack>=1.12.0 in /usr/local/lib/python3.13/dist-packages (from langgraph-checkpoint<5.0.0,>=4.1.0->langgraph<1.3.0,>=1.2.11->langchain) (1.12.2)
# Requirement already satisfied: orjson>=3.11.5 in /usr/local/lib/python3.13/dist-packages (from langgraph-sdk<0.5.0,>=0.4.2->langgraph<1.3.0,>=1.2.11->langchain) (3.12.0)
# Requirement already satisfied: websockets<17,>=14 in /usr/local/lib/python3.13/dist-packages (from langgraph-sdk<0.5.0,>=0.4.2->langgraph<1.3.0,>=1.2.11->langchain) (15.0.1)
# Requirement already satisfied: distro>=1.7.0 in /usr/local/lib/python3.13/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.6.0->langchain) (1.9.0)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /usr/local/lib/python3.13/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.6.0->langchain) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in /usr/local/lib/python3.13/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.6.0->langchain) (2.32.4)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.13/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.6.0->langchain) (1.3.1)
# Requirement already satisfied: zstandard>=0.23.0 in /usr/local/lib/python3.13/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.6.0->langchain) (0.25.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.13/dist-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.6.0->langchain) (3.4.9)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.13/dist-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.6.0->langchain) (2.5.0)
# Downloading langchain-1.4.0-py3-none-any.whl (161 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 161.5/161.5 kB 7.9 MB/s eta 0:00:00
# Installing collected packages: langchain
#   Attempting uninstall: langchain
#     Found existing installation: langchain 1.3.17
#     Uninstalling langchain-1.3.17:
#       Successfully uninstalled langchain-1.3.17
# Successfully installed langchain-1.4.0

# %%
import google.generativeai as genai
# Out:
# /usr/local/lib/python3.13/dist-packages/google/colab/_import_hooks/_hook_injector.py:55: FutureWarning:
#
# All support for the `google.generativeai` package has ended. It will no longer be receiving
# updates or bug fixes. Please switch to the `google.genai` package as soon as possible.
# See README for more details:
#
# https://github.com/google-gemini/deprecated-generative-ai-python/blob/main/README.md
#
#   loader.exec_module(module)

# %%
from google.colab import userdata

# %%
GOOGLE_API_KEY = userdata.get('Vaishnavi')

# %%
genai.configure(api_key=GOOGLE_API_KEY)

# %%
gemini_model = genai.GenerativeModel('gemini-3.5-flash')

# %%
prompt_text = "What is Generative AI?"

# %%
response = gemini_model.generate_content(prompt_text)

# %%
print(response.text)
# Out:
# **Generative Artificial Intelligence (Generative AI)** is a branch of artificial intelligence capable of generating new content—such as text, images, music, audio, video, or software code—in response to user prompts.
#
# Unlike traditional AI, which is designed to **analyze data or make decisions** (like spam filters or product recommendations), Generative AI is designed to **create something brand new** that resembles human-made content.
#
# ---
#
# ### How Does Generative AI Work? (In Simple Terms)
#
# Generative AI works using **machine learning models**, specifically deep learning, trained on massive datasets.
#
# 1. **Training:** The AI is fed billions of examples of existing content (e.g., books, articles, photos, songs, or code).
# 2. **Learning Patterns:** The AI analyzes this data to learn the underlying patterns, structures, and relationships. For example, it learns that the word "bacon" often follows "eggs," or that a human face usually has two eyes positioned above a nose.
# 3. **Prompting and Predicting:** When a user inputs a prompt (e.g., *"Write a poem about a robot"*), the AI doesn't copy-paste existing work. Instead, it uses probability to predict, word-by-word or pixel-by-pixel, what should come next based on what it learned during training.
#
# ---
#
# ### Common Types and Examples of Generative AI
#
# Generative AI is categorized by the type of content it produces:
#
# * **Text Generation:** Models like **ChatGPT** (OpenAI), **Claude** (Anthropic), and **Gemini** (Google) can write essays, answer questions, summarize long documents, translate languages, and draft emails.
# * **Image Generation:** Tools like **Midjourney**, **DALL-E 3**, and **Stable Diffusion** can create highly realistic photos, digital art, or 3D models from a simple text description.
# * **Code Generation:** Tools like **GitHub Copilot** can write, debug, and explain programming code in dozens of computer languages.
# * **Audio & Music Generation:** Platforms like **Suno** or **ElevenLabs** can generate complete songs with vocals, or create highly realistic text-to-speech voiceovers.
# * **Video Generation:** Tools like OpenAI’s **Sora** or **Runway** can generate realistic video clips from text prompts.
#
# ---
#
# ### Real-World Applications
#
# Generative AI is rapidly transforming various industries:
# * **Business & Marketing:** Writing copy, brainstorming ideas, and creating personalized advertisements.
# * **Customer Service:** Powering advanced chatbots that can understand and solve complex customer issues.
# * **Healthcare:** Helping researchers design new proteins and accelerate drug discovery.
# * **Entertainment:** Assisting game developers in creating virtual worlds and helping writers story-board films.
# * **Education:** Serving as personalized tutors that can explain complex topics in different ways tailored to the student.
#
# ---
#
# ### The Challenges and Risks of Generative AI
#
# While powerful, Generative AI has several limitations and ethical concerns:
#
# * **"Hallucinations":** Sometimes, these models confidently present false or fabricated information as fact.
# * **Copyright and Ethics:** Because AI is trained on data created by humans (artists, writers, programmers), there are major ongoing debates and lawsuits regarding intellectual property and whether creators should be compensated.
# * **Bias and Misinformation:** If the training data contains biases or inaccuracies, the AI will replicate them. It can also be used to create convincing **deepfakes** (fake images/videos) used for scams or political manipulation.
# * **Job Displacement:** There are concerns that Generative AI will replace human workers in creative and white-collar fields, such as writing, graphic design, and entry-level programming.
#
# ### Summary
# Generative AI is a shift from **computational AI** (calculating and organizing) to **creative AI** (generating and designing). It acts as a powerful co-pilot for human creativity, but requires careful supervision to ensure its output is accurate, ethical, and safe.

# %%
user_question = input("You: ")

response = gemini_model.generate_content(user_question)

print("Gemini:", response.text)
# Out:
# You: What is Deep Learning
# Gemini: **Deep Learning** is a subfield of Artificial Intelligence (AI) and Machine Learning (ML) that is inspired by the structure and function of the human brain.
#
# At its core, deep learning uses multi-layered artificial neural networks to learn from vast amounts of data. While traditional machine learning requires humans to manually program rules or identify features in data, deep learning algorithms can automatically discover these features on their own.
#
# Here is a breakdown of how it works, why it matters, and where it is used.
#
# ---
#
# ### 1. Where Deep Learning Fits (The AI Hierarchy)
# To understand deep learning, it helps to see how it fits into the broader picture of computer science:
# *   **Artificial Intelligence (AI):** The broad concept of enabling machines to mimic human intelligence.
# *   **Machine Learning (ML):** A subset of AI where computers learn from data without being explicitly programmed.
# *   **Deep Learning (DL):** A specialized subset of ML that uses "deep" neural networks to solve highly complex problems.
#
# ---
#
# ### 2. How Deep Learning Works: Neural Networks
# Deep learning gets its name from the "deep" layers of **Artificial Neural Networks (ANNs)**. These networks are modeled loosely after the biological neurons in the human brain.
#
# A typical deep neural network consists of three main parts:
# 1.  **The Input Layer:** Receives the raw data (e.g., an image of a handwritten number).
# 2.  **The Hidden Layers:** This is where the "deep" part comes in. A network might have dozens or hundreds of these layers. Each layer extracts progressively higher-level features from the input.
#     *   *Example:* If the network is analyzing a face, the first hidden layer might detect simple lines and edges. The next layer detects shapes (eyes, noses). The final hidden layers detect entire faces.
# 3.  **The Output Layer:** Gives the final prediction or decision (e.g., "This is the number 7" or "This is a cat").
#
# #### How does it learn? (Trial and Error)
# During training, the network is fed millions of labeled examples. It makes a guess, compares its guess to the correct answer, measures the error, and adjusts its internal connections (called **weights** and **biases**) using a mathematical process called **backpropagation**. It repeats this process millions of times until its predictions are highly accurate.
#
# ---
#
# ### 3. Machine Learning vs. Deep Learning: The Big Difference
# The major breakthrough of deep learning is **feature extraction**.
#
# *   **Traditional Machine Learning:** Requires human experts to identify the most important characteristics (features) in data. For example, to recognize cars, a programmer must tell the algorithm to look for wheels, windshields, and headlights.
# *   **Deep Learning:** You just feed the network thousands of raw images of cars. The network figures out on its own which features (wheels, headlights) are important for identifying a car.
#
# ---
#
# ### 4. Real-World Applications of Deep Learning
# Deep learning powers many of the most advanced technologies we use today:
#
# *   **Natural Language Processing (NLP):** Virtual assistants (Siri, Alexa), translation tools (Google Translate), and Large Language Models (like ChatGPT and Claude).
# *   **Computer Vision:** Facial recognition (Apple's FaceID), medical imaging (detecting tumors in X-rays), and self-driving cars (Tesla, Waymo detecting pedestrians and traffic lights).
# *   **Recommendation Systems:** How Netflix, Spotify, and TikTok predict what you want to watch or listen to next.
# *   **Generative AI:** Creating art, music, and text (Midjourney, DALL-E, Suno).
#
# ---
#
# ### 5. Why has Deep Learning exploded recently?
# While the theory behind deep learning has existed since the 1940s, it only became highly successful in the last decade due to three things:
# 1.  **Big Data:** The internet and smartphones created the massive datasets required to train these hungry algorithms.
# 2.  **Powerful Hardware:** Graphic Processing Units (GPUs) and Tensor Processing Units (TPUs), originally designed for video games, turned out to be perfect for the heavy mathematics required by deep learning.
# 3.  **Algorithmic Advances:** Researchers developed better mathematical techniques to train deeper networks without them breaking down.
#
# ---
#
# ### 6. Limitations of Deep Learning
# Despite its power, deep learning is not perfect:
# *   **Data Hungry:** It requires millions of data points to perform well.
# *   **Computationally Expensive:** Training state-of-the-art models requires massive amounts of electricity and expensive hardware.
# *   **The "Black Box" Problem:** Because the neural networks are so complex, it is often very difficult for human engineers to explain *why* a deep learning model made a specific decision.

# %%
while True:
    user_question = input("You: ")

    if user_question.lower() == "exit":
        print("Chatbot ended.")
        break

    response = gemini_model.generate_content(user_question)
    print("Gemini:", response.text)
# Out:
# You: what is AI
# Gemini: At its simplest, **Artificial Intelligence (AI)** is the ability of a computer or a robot to perform tasks that usually require human intelligence and discernment.
#
# While humans are born with natural intelligence, machines are programmed with artificial intelligence to mimic how humans **learn, reason, solve problems, and make decisions.**
#
# Here is a breakdown of what AI is, how it works, and how it is shaping our world.
#
# ---
#
# ### 1. How is AI different from normal computers?
# * **Traditional Computers:** Follow strict, pre-written rules. (e.g., "If the user clicks this button, open that file.")
# * **AI Systems:** Learn from experience and data. If you show an AI thousands of photos of cats, it will eventually figure out what a cat looks like on its own, without a human programmer defining "whiskers" or "pointy ears."
#
# ---
#
# ### 2. The Three Levels of AI
# Scientists generally divide AI into three categories based on its capabilities:
#
# 1. **Artificial Narrow Intelligence (ANI) or "Weak AI":**
#    * This AI is designed to do **one specific task** very well (e.g., play chess, recommend a movie, or drive a car).
#    * *Current status:* **This is the only type of AI that exists today.** Even advanced tools like ChatGPT or self-driving cars are still considered "Narrow" AI.
# 2. **Artificial General Intelligence (AGI) or "Strong AI":**
#    * This is AI that possesses human-level intelligence across the board. It could learn, understand, and apply knowledge to *any* intellectual task that a human can.
#    * *Current status:* **Theoretical.** Scientists do not know when (or if) we will achieve this.
# 3. **Artificial Superintelligence (ASI):**
#    * This is AI that surpasses human intelligence in every way—creative, social, and scientific.
#    * *Current status:* **Science fiction.**
#
# ---
#
# ### 3. Key Concepts Inside AI
# When people talk about AI, they often use terms like "Machine Learning" or "Neural Networks." Think of these as a Russian nesting doll:
#
# * **Artificial Intelligence (The Outer Doll):** The broad concept of machines acting smartly.
# * **Machine Learning (ML):** A subset of AI. Instead of coding rules, we feed a machine data and let it learn on its own.
# * **Deep Learning (DL):** A subset of ML that uses "artificial neural networks" (inspired by the human brain) to solve highly complex problems, like translating languages in real-time or diagnosing cancer from X-rays.
# * **Generative AI:** A newer branch of AI (like ChatGPT, Midjourney, or DALL-E) that can *generate* new content, such as text, images, music, or computer code.
#
# ---
#
# ### 4. Examples of AI in Daily Life
# You probably use AI dozens of times a day without realizing it:
# * **Smartphones:** FaceID, predictive text, and voice assistants (Siri, Google Assistant).
# * **Entertainment:** Netflix, Spotify, and YouTube algorithms that recommend what to watch or listen to next.
# * **Navigation:** Google Maps predicting traffic and finding the fastest route.
# * **Finance:** Fraud detection systems that alert you if your credit card is used suspiciously.
# * **Customer Service:** Chatbots on websites helping you return a package.
#
# ---
#
# ### 5. Why is AI so popular right now?
# AI has existed as a concept since the 1950s, but it has exploded recently due to three things:
# 1. **Massive Data:** The internet has provided billions of gigabytes of data to train AI.
# 2. **Powerful Computers:** Computer chips (especially GPUs) are now powerful enough to process this data.
# 3. **Generative AI:** The release of tools like ChatGPT made AI accessible to regular people, not just computer scientists.
#
# ---
#
# ### 6. The Challenges and Risks of AI
# While AI is incredibly useful, it also presents major challenges:
# * **Job Displacement:** AI is automating tasks once done by humans, from writing copy to analyzing data.
# * **Bias:** AI learns from human data. If the data contains biases (racism, sexism, etc.), the AI will repeat those biases.
# * **Deepfakes & Misinformation:** AI can create highly realistic fake videos, photos, and news stories, making it hard to know what is real.
# * **Privacy:** AI requires massive amounts of personal data to work effectively, raising surveillance concerns.
#
# ### Summary
# AI is not a "living mind" or a sci-fi robot; it is a **powerful tool** that excels at finding patterns in data and using those patterns to make predictions, solve problems, and generate new content.
# You: what is machine learning
# Gemini: At its simplest, **Machine Learning (ML)** is a branch of artificial intelligence (AI) that allows computers to learn and make decisions *without* being explicitly programmed to do so.
#
# Instead of a human writing code with specific rules for every scenario, machine learning uses **algorithms** to analyze massive amounts of data, find patterns, and make predictions or decisions based on that data.
#
# ---
#
# ### The Best Way to Understand It: Traditional vs. ML
#
# To understand machine learning, it helps to compare it to traditional computer programming.
#
# *   **Traditional Programming:** You give the computer **Data** and **Rules** (the code), and the computer gives you the **Answers**.
#     *   *Example:* If you want to block spam emails, you write a rule: "If the email contains the word 'Viagra' or 'free money,' move it to the spam folder."
# *   **Machine Learning:** You give the computer **Data** and the **Answers**, and the computer figures out the **Rules** on its own.
#     *   *Example:* You feed the computer 10,000 emails labeled "Spam" and 10,000 labeled "Not Spam." The ML algorithm analyzes them and detects subtle patterns (words, senders, formatting) that a human would never notice to create its own rules for blocking spam.
#
# ---
#
# ### The Three Main Types of Machine Learning
#
# Machine learning is generally divided into three categories, depending on how the algorithm learns:
#
# #### 1. Supervised Learning (The "Teacher-Student" Method)
# The computer is trained on a "labeled" dataset. This means you feed it data where you already know the correct answer.
# *   **How it works:** You show the computer 1,000 photos of cats and 1,000 photos of dogs, explicitly telling it, "This is a cat" or "This is a dog." Over time, it learns the features of each.
# *   **Use cases:** Spam detection, predicting house prices, medical diagnosis (detecting tumors in X-rays).
#
# #### 2. Unsupervised Learning (The "Detective" Method)
# The computer is given "unlabeled" data and must find patterns, groupings, or structures on its own.
# *   **How it works:** You give the computer a database of all your customers' purchasing habits. It groups them into "budget shoppers," "tech enthusiasts," and "impulse buyers" without you telling it what categories to look for.
# *   **Use cases:** Customer segmentation, recommendation engines (like Netflix or Spotify), detecting credit card fraud (finding "unusual" transactions).
#
# #### 3. Reinforcement Learning (The "Trial-and-Error" Method)
# The computer learns by interacting with an environment. It is given a goal and receives "rewards" for good decisions and "penalties" for bad ones.
# *   **How it works:** Think of training a dog with treats. In a video game, the AI gets points for staying alive and loses points for dying. Through millions of games, it learns the optimal strategy.
# *   **Use cases:** Self-driving cars, robotics, and chess-playing AIs (like Google’s AlphaGo).
#
# ---
#
# ### Where Do You Encounter Machine Learning Daily?
#
# You likely use machine learning dozens of times a day without realizing it:
# *   **Entertainment:** Netflix, YouTube, and Spotify algorithms predicting what you want to watch or listen to next.
# *   **Smartphones:** Facial recognition (FaceID), predictive text, and voice assistants (Siri, Alexa).
# *   **Finance:** Banks using ML to instantly approve loans or flag suspicious credit card activity.
# *   **Transportation:** Uber calculating your ride fare and arrival time, or Google Maps predicting traffic.
#
# ---
#
# ### AI vs. Machine Learning vs. Deep Learning
# These terms are often used interchangeably, but they are actually nested inside one another:
#
# 1.  **Artificial Intelligence (AI):** The broad concept of machines acting "smartly" (includes simple rules-based systems).
# 2.  **Machine Learning (ML):** A subset of AI where machines learn from data rather than rules.
# 3.  **Deep Learning (DL):** A advanced subset of ML that uses "neural networks" (mimicking the human brain) to solve highly complex problems, like translating languages or driving cars.
# You: exit
# Chatbot ended.
